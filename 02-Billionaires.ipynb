# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.
#
# > Again, **don't use ChatGPT for this assignment.** You should be able to memorize the most basic parts of pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** .

# %%
import pandas as pd

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`. Trying `read_excel` the first time will probably not work, you'll get an error message. Be sure to read the error carefully: *you probably need to install a new library before it will work, and the error tells you what the library is named*. You *might* need to do `Kernel > Restart Kernel...` and run the notebook again from the top in order to get it to work.

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.0.1)

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: openpyxl in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (3.1.4)
# Requirement already satisfied: numpy>=1.23.2 in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /Users/sofiaahmed/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("richpeople.xlsx")

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df.head()
# Out:
#    year                          name  rank           citizenship countrycode  \
# 0  2014          A. Jerrold Perenchio   663         United States         USA
# 1  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 2  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
# 3  2014             Abdullah Al Rajhi   731          Saudi Arabia         SAU
# 4  2014              Abdulsamad Rabiu  1372               Nigeria         NGA
#
#    networthusbillion   selfmade         typeofwealth gender   age  ...  \
# 0                2.6  self-made            executive   male  83.0  ...
# 1                2.5  inherited            inherited   male   NaN  ...
# 2                4.8  inherited            inherited   male   NaN  ...
# 3                2.4  self-made    self-made finance   male   NaN  ...
# 4                1.2  self-made  founder non-finance   male  54.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 0  former chairman and CEO       1955.0          NaN
# 1                 relation       1930.0          NaN
# 2                 relation       1960.0          NaN
# 3                  founder       1957.0          NaN
# 4                  founder       1988.0          NaN
#
#               sourceofwealth                                           notes  \
# 0      television, Univision  represented Marlon Brando and Elizabeth Taylor
# 1  auto dealers, investments    company split between him and cousin in 2000
# 2                diversified                           inherited from father
# 3                    banking                                             NaN
# 4       sugar, flour, cement                                             NaN
#
#    notes2                                           source  \
# 0     NaN     http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1     NaN    http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2     NaN    http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3     NaN       http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4     NaN  http://www.forbes.com/profile/abdulsamad-rabiu/
#
#                                             source_2  \
# 0  http://www.forbes.com/profile/a-jerrold-perenc...
# 1  http://www.al-futtaim.ae/content/groupProfile.asp
# 2      http://www.alghurair.com/about-us/our-history
# 3  http://www.alrajhibank.com.sa/ar/investor-rela...
# 4  http://www.bloomberg.com/research/stocks/priva...
#
#                                             source_3 source_4
# 0  COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3  http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 4                                                NaN      NaN
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#       year                name  rank citizenship countrycode  \
# 1648  2014           Zhu Yicai  1154       China         CHN
# 1649  2014       Ziyad Manasir   609      Russia         RUS
# 1650  2014  Ziyaudin Magomedov  1372      Russia         RUS
# 1651  2014        Zong Qinghou    94       China         CHN
# 1652  2014  Zygmunt Solorz-Zak   446      Poland         POL
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 1648                1.5  self-made         self-made finance   male  49.0
# 1649                2.8  self-made  privatized and resources   male  48.0
# 1650                1.2  self-made  privatized and resources   male  45.0
# 1651               11.6  self-made       founder non-finance   male  68.0
# 1652                3.5  self-made       founder non-finance   male  57.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus   sourceofwealth  \
# 1648  ...               founder       1993.0          NaN      diversified
# 1649  ...               founder       1992.0          NaN     construction
# 1650  ...               founder       2004.0          NaN        port, gas
# 1651  ...               founder       1987.0          NaN        beverages
# 1652  ...               founder       1992.0          NaN  TV broadcasting
#
#                         notes  notes2  \
# 1648                      NaN     NaN
# 1649  close ties with Gazprom     NaN
# 1650                      NaN     NaN
# 1651                      NaN     NaN
# 1652                      NaN     NaN
#
#                                                  source  \
# 1648           http://www.forbes.com/profile/zhu-yicai/
# 1649       http://www.forbes.com/profile/ziyad-manasir/
# 1650         http://www.summagroup.ru/about/history/en/
# 1651          http://en.wikipedia.org/wiki/Zong_Qinghou
# 1652  http://en.wikipedia.org/wiki/Zygmunt_Solorz-%C...
#
#                                                source_2 source_3 source_4
# 1648                                                NaN      NaN      NaN
# 1649  http://www.themoscowtimes.com/business/article...      NaN      NaN
# 1650  http://www.forbes.com/profile/ziyaudin-magomedov/      NaN      NaN
# 1651  http://mic.com/articles/39659/zong-qinghou-chi...      NaN      NaN
# 1652  No Mob Bosses in This Legal Strategy The New Y...      NaN      NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values('networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 339   2014        David Koch     6  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# 79                 64.0  self-made       founder non-finance    male  77.0
# 1562               58.2  self-made       founder non-finance    male  83.0
# 862                48.0  self-made       founder non-finance    male  69.0
# 339                40.0  inherited                 inherited    male  73.0
# 247                40.0  inherited                 inherited    male  78.0
# 1364               38.0  self-made         self-made finance    male  80.0
# 280                36.7  inherited                 inherited  female  59.0
# 724                34.7  inherited                 inherited    male  66.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus      sourceofwealth  \
# 184   ...               founder       1975.0          NaN           Microsoft
# 226   ...               founder       1990.0          NaN             telecom
# 79    ...               founder       1975.0          NaN              retail
# 1562  ...               founder       1839.0          NaN  Berkshire Hathaway
# 862   ...               founder       1977.0          NaN              Oracle
# 339   ...              relation       1940.0          NaN         diversified
# 247   ...              relation       1940.0          NaN         diversified
# 1364  ...               founder       1952.0          NaN             casinos
# 280   ...              relation       1962.0          NaN            Wal-Mart
# 724   ...              relation       1962.0          NaN            Wal-Mart
#
#                       notes  notes2  \
# 184                     NaN     NaN
# 226                     NaN     NaN
# 79                      NaN     NaN
# 1562                    NaN     NaN
# 862                     NaN     NaN
# 339   inherited from father     NaN
# 247   inherited from father     NaN
# 1364                    NaN     NaN
# 280                   widow     NaN
# 724   inherited from father     NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 339   http://www.kochind.com/About_Koch/History_Time...
# 247   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 184                                                 NaN      NaN      NaN
# 226                                                 NaN      NaN      NaN
# 79                                                  NaN      NaN      NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 862   http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 339                                                 NaN      NaN      NaN
# 247                                                 NaN      NaN      NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 280                                                 NaN      NaN      NaN
# 724                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 4a) How many male billionaires are there compared to the number of female billionares?
#
# > **TIP:** This is not a `.groupby`

# %%
ladies_df = df[df['gender'] == 'female']
ladies_df
# Out:
#       year                      name  rank     citizenship countrycode  \
# 5     2014           Abigail Johnson    50   United States         USA
# 9     2014  Aerin Lauder Zinterhofer  1465   United States         USA
# 12    2014              Ahsen Ozokur  1143          Turkey         TUR
# 52    2014     Alexandra Schorghuber   609         Germany         DEU
# 67    2014              Alice Walton    13   United States         USA
# ...    ...                       ...   ...             ...         ...
# 1603  2014             Xiu Li Hawken  1372  United Kingdom         GBR
# 1607  2014               Yang Huiyan   196           China         CHN
# 1618  2014              Yoshiko Mori  1210           Japan         JPN
# 1627  2014              Yvonne Bauer   446         Germany         DEU
# 1638  2014                 Zhang Xin   408           China         CHN
#
#       networthusbillion   selfmade       typeofwealth  gender   age  ...  \
# 5                  17.3  inherited          inherited  female  52.0  ...
# 9                   1.1  inherited          inherited  female  44.0  ...
# 12                  1.6  inherited          inherited  female  63.0  ...
# 52                  2.8  inherited          inherited  female  55.0  ...
# 67                 34.3  inherited          inherited  female  64.0  ...
# ...                 ...        ...                ...     ...   ...  ...
# 1603                1.2  self-made  self-made finance  female  51.0  ...
# 1607                6.9  inherited          inherited  female  32.0  ...
# 1618                1.4  inherited          inherited  female  73.0  ...
# 1627                3.5  inherited          inherited  female  36.0  ...
# 1638                3.7  self-made  self-made finance  female  48.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 5                 relation       1946.0          NaN
# 9                 relation       1946.0          NaN
# 12                relation       1944.0          NaN
# 52                relation       1954.0          NaN
# 67                relation       1962.0          NaN
# ...                    ...          ...          ...
# 1603                 owner       2007.0          NaN
# 1607              relation       1997.0          NaN
# 1618              relation       1959.0          NaN
# 1627              relation       1875.0          NaN
# 1638               founder       1995.0          NaN
#
#                 sourceofwealth                  notes  \
# 5             money management         3rd generation
# 9         inherited, cosmetics         3rd generation
# 12          food manufacturing  inherited from father
# 52                 real estate                  widow
# 67                    Wal-Mart  inherited from father
# ...                        ...                    ...
# 1603               real estate                    NaN
# 1607               real estate  inherited from father
# 1618  inherited, Mori Building                  widow
# 1627                     media         5th generation
# 1638               real estate                    NaN
#
#                                                  notes2  \
# 5                                      no male siblings
# 9                                                   NaN
# 12                                          shareholder
# 52                                                  NaN
# 67                                                  NaN
# ...                                                 ...
# 1603                                                NaN
# 1607                                                NaN
# 1618                                                NaN
# 1627  chairman, three sisters have 5% ownership in c...
# 1638                                                NaN
#
#                                                  source  \
# 5      http://en.wikipedia.org/wiki/Edward_Johnson,_III
# 9              http://en.wikipedia.org/wiki/Jane_Lauder
# 12              http://en.wikipedia.org/wiki/%C3%9Clker
# 52    http://de.wikipedia.org/wiki/Sch%C3%B6rghuber_...
# 67    http://www.forbes.com/profile/nancy-walton-lau...
# ...                                                 ...
# 1603       http://www.forbes.com/profile/xiu-li-hawken/
# 1607           http://en.wikipedia.org/wiki/Yang_Huiyan
# 1618        http://www.forbes.com/profile/yoshiko-mori/
# 1627        http://www.forbes.com/profile/yvonne-bauer/
# 1638  http://en.wikipedia.org/wiki/Zhang_Xin_(busine...
#
#                                                source_2  \
# 5     https://www.fidelity.com/about-fidelity/our-he...
# 9     http://investing.businessweek.com/research/sto...
# 12        http://www.yildizholding.com.tr/tr/hakkimizda
# 52    http://de.wikipedia.org/wiki/Alexandra_Sch%C3%...
# 67                                                  NaN
# ...                                                 ...
# 1603  http://investing.businessweek.com/research/sto...
# 1607                                                NaN
# 1618                                                NaN
# 1627     http://en.wikipedia.org/wiki/Bauer_Media_Group
# 1638                                                NaN
#
#                                                source_3 source_4
# 5                                                   NaN      NaN
# 9                                                   NaN      NaN
# 12                                                  NaN      NaN
# 52    http://www.sug-munich.com/de/unternehmensgrupp...      NaN
# 67                                                  NaN      NaN
# ...                                                 ...      ...
# 1603                                                NaN      NaN
# 1607                                                NaN      NaN
# 1618                                                NaN      NaN
# 1627                                                NaN      NaN
# 1638                                                NaN      NaN
#
# [180 rows x 30 columns]

# %%
df[df['gender'] == 'female']
# Out:
#       year                      name  rank     citizenship countrycode  \
# 5     2014           Abigail Johnson    50   United States         USA
# 9     2014  Aerin Lauder Zinterhofer  1465   United States         USA
# 12    2014              Ahsen Ozokur  1143          Turkey         TUR
# 52    2014     Alexandra Schorghuber   609         Germany         DEU
# 67    2014              Alice Walton    13   United States         USA
# ...    ...                       ...   ...             ...         ...
# 1603  2014             Xiu Li Hawken  1372  United Kingdom         GBR
# 1607  2014               Yang Huiyan   196           China         CHN
# 1618  2014              Yoshiko Mori  1210           Japan         JPN
# 1627  2014              Yvonne Bauer   446         Germany         DEU
# 1638  2014                 Zhang Xin   408           China         CHN
#
#       networthusbillion   selfmade       typeofwealth  gender   age  ...  \
# 5                  17.3  inherited          inherited  female  52.0  ...
# 9                   1.1  inherited          inherited  female  44.0  ...
# 12                  1.6  inherited          inherited  female  63.0  ...
# 52                  2.8  inherited          inherited  female  55.0  ...
# 67                 34.3  inherited          inherited  female  64.0  ...
# ...                 ...        ...                ...     ...   ...  ...
# 1603                1.2  self-made  self-made finance  female  51.0  ...
# 1607                6.9  inherited          inherited  female  32.0  ...
# 1618                1.4  inherited          inherited  female  73.0  ...
# 1627                3.5  inherited          inherited  female  36.0  ...
# 1638                3.7  self-made  self-made finance  female  48.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 5                 relation       1946.0          NaN
# 9                 relation       1946.0          NaN
# 12                relation       1944.0          NaN
# 52                relation       1954.0          NaN
# 67                relation       1962.0          NaN
# ...                    ...          ...          ...
# 1603                 owner       2007.0          NaN
# 1607              relation       1997.0          NaN
# 1618              relation       1959.0          NaN
# 1627              relation       1875.0          NaN
# 1638               founder       1995.0          NaN
#
#                 sourceofwealth                  notes  \
# 5             money management         3rd generation
# 9         inherited, cosmetics         3rd generation
# 12          food manufacturing  inherited from father
# 52                 real estate                  widow
# 67                    Wal-Mart  inherited from father
# ...                        ...                    ...
# 1603               real estate                    NaN
# 1607               real estate  inherited from father
# 1618  inherited, Mori Building                  widow
# 1627                     media         5th generation
# 1638               real estate                    NaN
#
#                                                  notes2  \
# 5                                      no male siblings
# 9                                                   NaN
# 12                                          shareholder
# 52                                                  NaN
# 67                                                  NaN
# ...                                                 ...
# 1603                                                NaN
# 1607                                                NaN
# 1618                                                NaN
# 1627  chairman, three sisters have 5% ownership in c...
# 1638                                                NaN
#
#                                                  source  \
# 5      http://en.wikipedia.org/wiki/Edward_Johnson,_III
# 9              http://en.wikipedia.org/wiki/Jane_Lauder
# 12              http://en.wikipedia.org/wiki/%C3%9Clker
# 52    http://de.wikipedia.org/wiki/Sch%C3%B6rghuber_...
# 67    http://www.forbes.com/profile/nancy-walton-lau...
# ...                                                 ...
# 1603       http://www.forbes.com/profile/xiu-li-hawken/
# 1607           http://en.wikipedia.org/wiki/Yang_Huiyan
# 1618        http://www.forbes.com/profile/yoshiko-mori/
# 1627        http://www.forbes.com/profile/yvonne-bauer/
# 1638  http://en.wikipedia.org/wiki/Zhang_Xin_(busine...
#
#                                                source_2  \
# 5     https://www.fidelity.com/about-fidelity/our-he...
# 9     http://investing.businessweek.com/research/sto...
# 12        http://www.yildizholding.com.tr/tr/hakkimizda
# 52    http://de.wikipedia.org/wiki/Alexandra_Sch%C3%...
# 67                                                  NaN
# ...                                                 ...
# 1603  http://investing.businessweek.com/research/sto...
# 1607                                                NaN
# 1618                                                NaN
# 1627     http://en.wikipedia.org/wiki/Bauer_Media_Group
# 1638                                                NaN
#
#                                                source_3 source_4
# 5                                                   NaN      NaN
# 9                                                   NaN      NaN
# 12                                                  NaN      NaN
# 52    http://www.sug-munich.com/de/unternehmensgrupp...      NaN
# 67                                                  NaN      NaN
# ...                                                 ...      ...
# 1603                                                NaN      NaN
# 1607                                                NaN      NaN
# 1618                                                NaN      NaN
# 1627                                                NaN      NaN
# 1638                                                NaN      NaN
#
# [180 rows x 30 columns]

# %%
df['gender'].value_counts()
# Out:
# gender
# male      1473
# female     180
# Name: count, dtype: int64

# %% [markdown]
# ## 4b) What percent is that?
#
# > **TIP:** Doing percentages with the answer to `4a` is so common that there's an extra parameter to automatically calculate it. Look at the documentation!

# %%
df['gender'].value_counts(normalize=True) *100
# Out:
# gender
# male      89.110708
# female    10.889292
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4c) Is the average wealth different for a female billionaire as compared to a male billionaire?
#
# > **TIP:** This one *does* use `.groupby`. You can pick what 'average' means in this context.

# %%
df.groupby('gender')['networthusbillion'].mean()
# Out:
# gender
# female    3.920556
# male      3.902716
# Name: networthusbillion, dtype: float64

# %%
#groupby - from what - from where

# %% [markdown]
# ## 5a) What is the most common source/type of wealth?

# %%
df['typeofwealth'].value_counts()
# Out:
# typeofwealth
# inherited                   506
# founder non-finance         467
# self-made finance           344
# privatized and resources    192
# executive                   142
# Name: count, dtype: int64

# %% [markdown]
# ## 5b) Is the most common source/type of wealth different between men and women?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together??? You could also do this as two separate cells where you calculate it separately for men and women.
# >
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
df.groupby('gender')['typeofwealth'].value_counts(normalize=True) *100
# Out:
# gender  typeofwealth
# female  inherited                   78.888889
#         founder non-finance         11.666667
#         executive                    3.333333
#         self-made finance            3.333333
#         privatized and resources     2.777778
# male    founder non-finance         30.319511
#         inherited                   24.745071
#         self-made finance           22.977566
#         privatized and resources    12.712441
#         executive                    9.245411
# Name: proportion, dtype: float64

# %% [markdown]
# ## 6a) What companies have the most billionaires? Let's see the top five.
#
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
df['company'].value_counts().head(5)
# Out:
# company
# Hyatt                  11
# Oetker-Gruppe           8
# S. C. Johnson & Son     7
# Alfa Group              6
# Votorantim Group        6
# Name: count, dtype: int64

# %%
df_company = df['company'].value_counts().head(5)

# %% [markdown]
# ### 6b) Graph those top 5 as a horizontal bar graph. Make the largest bar be at the top of the graph.
#
# > **TIP:** Just try to throw `.plot()` on the end??
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
df_company.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5 entries, Hyatt to Votorantim Group
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 80.0+ bytes

# %%
df_company.sort_values().plot.barh()
# Out:
# <Axes: ylabel='company'>

# %% [markdown]
# ## 7) How much money do these top 5 billionaires have in total?
#
# > **TIP:** for multiple conditions, you can't use `or` and `and`. In pandas, `|` means *or* and `&` means *and*.
# >
# > **TIP:** Checking multiple conditions can be done two ways.
# > - `(df.colname == 'A') | (df.colname == 'B')`
# > - `df.colname.isin(['A', 'B'])`

# %%
df[df.company.isin(company_list)]['networthusbillion'].sum()
# Out:
# 120.30000000000001

# %%
df_company.index.tolist()
# Out:
# ['Hyatt',
#  'Oetker-Gruppe',
#  'S. C. Johnson & Son',
#  'Alfa Group',
#  'Votorantim Group']

# %%
company_list = df_company.index.tolist()

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
.sum['networthusbillion']

# %%
df.groupby('citizenship')['networthusbillion'].sum().sort_values(ascending=False).head(10)
# Out:
# citizenship
# United States     2322.4
# Russia             422.5
# Germany            401.4
# China              375.8
# France             235.3
# Hong Kong          213.7
# Brazil             192.2
# India              191.9
# Italy              158.1
# United Kingdom     152.0
# Name: networthusbillion, dtype: float64

# %%
df['citizenship']
# Out:
# 0              United States
# 1       United Arab Emirates
# 2       United Arab Emirates
# 3               Saudi Arabia
# 4                    Nigeria
#                 ...
# 1648                   China
# 1649                  Russia
# 1650                  Russia
# 1651                   China
# 1652                  Poland
# Name: citizenship, Length: 1653, dtype: object

# %% [markdown]
# ## 9a) How old is an average billionaire?

# %%
df['age'].mean
# Out:
# <bound method Series.mean of 0       83.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4       54.0
#         ...
# 1648    49.0
# 1649    48.0
# 1650    45.0
# 1651    68.0
# 1652    57.0
# Name: age, Length: 1653, dtype: float64>

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %% [markdown]
# ## 9b) How old are self-made billionaires compared to non self-made billionaires?

# %%
df.groupby('selfmade')['age'].mean()
# Out:
# selfmade
# inherited    64.962185
# self-made    62.625899
# Name: age, dtype: float64

# %% [markdown]
# ## 10a) Who are the three youngest billionaires? Who are the three oldest?

# %%
df.sort_values('age').head(3)
# Out:
#       year              name  rank    citizenship countrycode  \
# 1172  2014       Perenna Kei  1284      Hong Kong         HKG
# 397   2014  Dustin Moskovitz   202  United States         USA
# 1004  2014   Mark Zuckerberg    21  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  ...  \
# 1172                1.3  inherited            inherited  female  24.0  ...
# 397                 6.8  self-made  founder non-finance    male  29.0  ...
# 1004               28.5  self-made  founder non-finance    male  29.0  ...
#
#      relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  \
# 1172              relation       1996.0          NaN     real estate
# 397                founder       2004.0          NaN        Facebook
# 1004               founder       2004.0          NaN        Facebook
#
#                       notes  notes2  \
# 1172  inherited from father     NaN
# 397                     NaN     NaN
# 1004                    NaN     NaN
#
#                                               source  \
# 1172        http://en.wikipedia.org/wiki/Perenna_Kei
# 397    http://en.wikipedia.org/wiki/Dustin_Moskovitz
# 1004  http://www.forbes.com/profile/mark-zuckerberg/
#
#                                                source_2  \
# 1172  http://www.loganestate.com/en/about.aspx?ftid=294
# 397     http://www.forbes.com/profile/dustin-moskovitz/
# 1004                                                NaN
#
#                                                source_3 source_4
# 1172                                                NaN      NaN
# 397   https://www.facebook.com/facebook/info?tab=pag...      NaN
# 1004                                                NaN      NaN
#
# [3 rows x 30 columns]

# %%
df.sort_values('age').tail(3)
# Out:
#       year                name  rank citizenship countrycode  \
# 1516  2014  Victor Civita Neto  1540      Brazil         BRA
# 1555  2014            Wang Wei   375       China         CHN
# 1598  2014            Wu Xiong  1565       China         CHN
#
#       networthusbillion   selfmade         typeofwealth gender  age  ...  \
# 1516                1.1  inherited            inherited   male  NaN  ...
# 1555                4.0  self-made  founder non-finance   male  NaN  ...
# 1598                1.0  self-made            executive   male  NaN  ...
#
#      relationshiptocompany foundingdate gdpcurrentus    sourceofwealth  \
# 1516              relation       1950.0          NaN             media
# 1555               founder       1993.0          NaN  delivery service
# 1598                 owner       1999.0          NaN    infant formula
#
#                                                   notes  notes2  \
# 1516                                     3rd generation     NaN
# 1555  2013 Saw investment from outside investors wit...     NaN
# 1598                                                NaN     NaN
#
#                                                  source source_2 source_3  \
# 1516  http://www.forbes.com/profile/roberta-anamaria...      NaN      NaN
# 1555            http://www.forbes.com/profile/wang-wei/      NaN      NaN
# 1598            http://www.forbes.com/profile/wu-xiong/      NaN      NaN
#
#      source_4
# 1516      NaN
# 1555      NaN
# 1598      NaN
#
# [3 rows x 30 columns]

# %% [markdown]
# ## 10b) Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %%
df['age'].plot(kind='hist', title = "Distribution of billionaires' ages")
# Out:
# <Axes: title={'center': "Distribution of billionaires' ages"}, ylabel='Frequency'>

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age
#
# It's more fun to do this in Altair as compared to matplotlib, but either is fine.

# %%
df.plot(kind='scatter', x = 'age', y = 'networthusbillion')
# Out:
# <Axes: xlabel='age', ylabel='networthusbillion'>

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %% [markdown]
# ## 14) Read in the most recent data
#
# I copied and pasted the most recent data from [the original Bloomberg story](https://www.bloomberg.com/billionaires/) (it's in the page's source code), but it all was saved as JSON. Can you use pandas to read in `billionaires.json`?
#
# > **TIP:** If `pd.read_csv` reads a CSV and `pd.read_excel` reads an excel file... what reads in JSON?
# >
# > **TIP:** It's a lot less complicated than what we did in class.

# %%
pd.read_json("billionaires.json")
# Out:
#                  commonName commonLastName     citizenship  \
# 0                 Elon Musk           Musk   United States
# 1           Bernard Arnault        Arnault          France
# 2                Jeff Bezos          Bezos   United States
# 3                Bill Gates          Gates   United States
# 4             Larry Ellison        Ellison   United States
# ..                      ...            ...             ...
# 495  Sofie Kirk Kristiansen    Kristiansen         Denmark
# 496     Frits Goldschmeding  Goldschmeding     Netherlands
# 497          Austen Cargill        Cargill   United States
# 498              John Reece          Reece  United Kingdom
# 499        Patrick Collison       Collison         Ireland
#
#                          slug     industry  personId  rank         worth  \
# 0                 elon-r-musk   Technology   1954518     1  221116780866
# 1           bernard-j-arnault     Consumer   1392853     2  170267873036
# 2             jeffrey-p-bezos   Technology   1642252     3  169556171871
# 3             william-h-gates   Technology   1390479     4  131137012631
# 4          lawrence-j-ellison   Technology   1491757     5  129608081535
# ..                        ...          ...       ...   ...           ...
# 495  sofie-kirk-k-kristiansen     Consumer  17992920   496    5145062341
# 496     frits-j-goldschmeding       Retail   3368283   497    5136282642
# 497          austen-s-cargill  Commodities   1878644   498    5132489050
# 498                john-reece   Industrial  18070530   499    5125353358
# 499          patrick-collison   Technology  17559658   500    5118900000
#
#      lastChange  lastPercentChange    ytdChange  ytdPercentChange  \
# 0    9795811154               4.64  84106712938             61.39
# 1    7356040557               4.52   8178459368              5.05
# 2    3202661603               1.93  62599942079             58.53
# 3    1103482475               0.85  21900118029             20.05
# 4    2286642464               1.80  37780140594             41.14
# ..          ...                ...          ...               ...
# 495    33748968               0.66   -292738682             -5.38
# 496   154239727               3.10     -7773499             -0.15
# 497           0               0.00     38448500              0.75
# 498           0               0.00   1839914334             56.00
# 499           0               0.00  -3175100000            -38.28
#
#           sector  fWorth fLastChange fYtdChange fLastPercentChange  \
# 0     Technology   $221B     +$9.80B    +$84.1B              +4.6%
# 1       Consumer   $170B     +$7.36B    +$8.18B              +4.5%
# 2     Technology   $170B     +$3.20B    +$62.6B              +1.9%
# 3     Technology   $131B     +$1.10B    +$21.9B              +0.8%
# 4     Technology   $130B     +$2.29B    +$37.8B              +1.8%
# ..           ...     ...         ...        ...                ...
# 495     Consumer  $5.15B     +$33.7M     -$293M              +0.7%
# 496       Retail  $5.14B      +$154M    -$7.77M              +3.1%
# 497  Commodities  $5.13B          $0    +$38.4M                 0%
# 498   Industrial  $5.13B          $0    +$1.84B                 0%
# 499   Technology  $5.12B          $0    -$3.18B                 0%
#
#     fYtdPercentChange
# 0              +61.4%
# 1               +5.0%
# 2              +58.5%
# 3              +20.1%
# 4              +41.1%
# ..                ...
# 495             -5.4%
# 496             -0.1%
# 497             +0.8%
# 498            +56.0%
# 499            -38.3%
#
# [500 rows x 18 columns]
